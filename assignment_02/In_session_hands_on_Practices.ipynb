# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreecr7/data690_Sree/blob/main/assignment_02/In_session_hands_on_Practices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In-session Hands-on Practices
# Sree Purani

# %% [markdown]
# #1.Simple Type

# %%
x= 5 #integer
y= 0.5 #float
s= "Hello" #string collection of character 
print(x,y,s)
# Out:
# 5 0.5 Hello

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %% [markdown]
# #2. Collection Type

# %%
a_list = [1,4,7,10]

print(a_list)
# Out:
# [1, 4, 7, 10]

# %%
type(a_list)
# Out:
# list

# %% [markdown]
# ## 3. Loop

# %%
for i in a_list:
  print("integer",i)
# Out:
# integer 1
# integer 4
# integer 7
# integer 10

# %% [markdown]
# ##4. Conditions

# %%
print(10%2) #modula
# Out:
# 0

# %%
print(23%2) #modula
# Out:
# 1

# %%
for i in a_list:
  if i%2 ==1:
    print("odd number",i)
# Out:
# odd number 1
# odd number 7
